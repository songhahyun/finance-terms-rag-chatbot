# %%
import pandas as pd

# %%
# testset = pd.read_csv("eval/rag_testset.csv", encoding="utf-8")
testset = pd.read_csv("eval/golden_testset.csv", encoding="utf-8")
testset
# Out:
#                                                ﻿query difficulty  \
# 0                              가계부실위험지수(HDRI)는 무엇인가요?          하
# 1                                    가산금리란 무엇을 의미하나요?          하
# 2                                        기준금리는 무엇입니까?          하
# 3                                      담보인정비율(LTV)이란?          하
# 4                       총부채원리금상환비율(DSR)이 무엇인지 설명해주세요.          하
# 5                                  디커플링 현상은 무엇을 뜻하나요?          하
# 6                            양도성예금증서(CD)는 어떤 금융상품인가요?          하
# 7                                   기업어음(CP)이란 무엇인가요?          하
# 8                             고객확인절차(KYC)의 의미를 알려주세요.          하
# 9                             부가가치기준 무역(TiVA)은 무엇인가요?          하
# 10                             금리선물과 금리스왑의 차이는 무엇인가요?          중
# 11            양도성예금증서(CD)와 기업어음(CP)의 특징과 차이점을 설명해주세요.          중
# 12                   선물환거래와 차액결제선물환(NDF)거래는 어떻게 다른가요?          중
# ...
