# %% [markdown]
# # 01 Data Ingestion
#
# `src.ingestion` ??? ??? PDF? ???? `data/processed/final_chunk.json`? ?????.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

print(f"Project root: {ROOT}")

# %%
from src.common.config import get_settings
from src.ingestion.pipeline import run_ingestion

settings = get_settings()
settings

# %%
chunks = run_ingestion(
    pdf_path=settings.default_pdf_path,
    output_json_path=settings.default_chunk_json_path,
    remove_noise_terms=["ABC"],
    use_kiwi=True,
)
print(f"Saved chunks: {len(chunks)}")
print(chunks[0]["chunk_id"], chunks[0]["??"])
